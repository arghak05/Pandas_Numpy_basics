# %%
import pandas as pd

# %%
df = pd.read_csv('G:/PANDAS/Datasets/Player.csv')

# %%
df
# Out:
#      Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0            1       SC Ganguly   8-Jul-72    Left_Hand    Right-arm medium
# 1            2      BB McCullum  27-Sep-81   Right_Hand    Right-arm medium
# 2            3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3            4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4            5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
# ..         ...              ...        ...          ...                 ...
# 518        519      Subroto Das        NaN          NaN                 NaN
# 519        520     K Srinivasan        NaN          NaN                 NaN
# 520        521        VK Sharma        NaN          NaN                 NaN
# 521        523      AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524      B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#          Country  Is_Umpire  Unnamed: 7
# ...

# %%
df.head(20)
# Out:
#     Player_Id      Player_Name        DOB Batting_Hand  \
# 0           1       SC Ganguly   8-Jul-72    Left_Hand
# 1           2      BB McCullum  27-Sep-81   Right_Hand
# 2           3       RT Ponting  19-Dec-74   Right_Hand
# 3           4        DJ Hussey  15-Jul-77   Right_Hand
# 4           5  Mohammad Hafeez  17-Oct-80   Right_Hand
# 5           6         R Dravid  11-Jan-73   Right_Hand
# 6           7         W Jaffer  16-Feb-78   Right_Hand
# 7           8          V Kohli   5-Nov-88   Right_Hand
# 8           9        JH Kallis  16-Oct-75   Right_Hand
# 9          10         CL White  18-Aug-83   Right_Hand
# 10         11       MV Boucher   3-Dec-76   Right_Hand
# 11         12          B Akhil   7-Oct-77   Right_Hand
# 12         13        AA Noffke  30-Apr-77   Right_Hand
# 13         14          P Kumar   2-Oct-86   Right_Hand
# 14         15           Z Khan   7-Oct-78   Right_Hand
# 15         16         SB Joshi   6-Jun-70    Left_Hand
# ...

# %%
df.tail()
# Out:
#      Player_Id   Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 518        519   Subroto Das        NaN          NaN                 NaN
# 519        520  K Srinivasan        NaN          NaN                 NaN
# 520        521     VK Sharma        NaN          NaN                 NaN
# 521        523   AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524   B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#     Country  Is_Umpire  Unnamed: 7
# 518   India          1         NaN
# 519   India          1         NaN
# 520   India          1         NaN
# 521   India          0         NaN
# 522   India          0         NaN

# %%
pd.read_csv('G:/PANDAS/Datasets/Player.csv')
# Out:
#      Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0            1       SC Ganguly   8-Jul-72    Left_Hand    Right-arm medium
# 1            2      BB McCullum  27-Sep-81   Right_Hand    Right-arm medium
# 2            3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3            4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4            5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
# ..         ...              ...        ...          ...                 ...
# 518        519      Subroto Das        NaN          NaN                 NaN
# 519        520     K Srinivasan        NaN          NaN                 NaN
# 520        521        VK Sharma        NaN          NaN                 NaN
# 521        523      AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524      B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#          Country  Is_Umpire  Unnamed: 7
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df1  =  df.head()

# %%
df.tail()
# Out:
#      Player_Id   Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 518        519   Subroto Das        NaN          NaN                 NaN
# 519        520  K Srinivasan        NaN          NaN                 NaN
# 520        521     VK Sharma        NaN          NaN                 NaN
# 521        523   AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524   B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#     Country  Is_Umpire  Unnamed: 7
# 518   India          1         NaN
# 519   India          1         NaN
# 520   India          1         NaN
# 521   India          0         NaN
# 522   India          0         NaN

# %%
df1.to_csv("G:/PANDAS/Datasets/test.csv")

# %%
ls
# Out:
#  Volume in drive G is New Volume
#  Volume Serial Number is C8FA-B8A9
#
#  Directory of G:\PANDAS
#
# 21-01-2023  14:08    <DIR>          .
# 21-01-2023  14:08    <DIR>          ..
# 21-01-2023  13:26    <DIR>          .ipynb_checkpoints
# 21-01-2023  14:08    <DIR>          Datasets
# 21-01-2023  14:08            44,907 Pandas_1.ipynb
# 21-01-2023  13:12           294,129 pandas_data_manupulations.ipynb
#                2 File(s)        339,036 bytes
#                4 Dir(s)  297,990,537,216 bytes free

# %%
pd.read_csv('G:/PANDAS/Datasets/test.csv')
# Out:
#    Unnamed: 0  Player_Id      Player_Name        DOB Batting_Hand  \
# 0           0          1       SC Ganguly   8-Jul-72    Left_Hand
# 1           1          2      BB McCullum  27-Sep-81   Right_Hand
# 2           2          3       RT Ponting  19-Dec-74   Right_Hand
# 3           3          4        DJ Hussey  15-Jul-77   Right_Hand
# 4           4          5  Mohammad Hafeez  17-Oct-80   Right_Hand
#
#         Bowling_Skill      Country  Is_Umpire  Unnamed: 7
# 0    Right-arm medium        India          0         NaN
# 1    Right-arm medium  New Zealand          0         NaN
# 2    Right-arm medium    Australia          0         NaN
# 3  Right-arm offbreak    Australia          0         NaN
# 4  Right-arm offbreak     Pakistan          0         NaN

# %%
df = pd.read_csv('G:/PANDAS/Datasets/Player_new_seperator.csv',sep='#',header=None,names=['a','b','c','d','e','f','g','h'],skiprows=[0,4,6,8])

# %%
df
# Out:
#        a                b          c           d                   e  \
# 0      1       SC Ganguly   8-Jul-72   Left_Hand    Right-arm medium
# 1      2      BB McCullum  27-Sep-81  Right_Hand    Right-arm medium
# 2      3       RT Ponting  19-Dec-74  Right_Hand    Right-arm medium
# 3      5  Mohammad Hafeez  17-Oct-80  Right_Hand  Right-arm offbreak
# 4      7         W Jaffer  16-Feb-78  Right_Hand  Right-arm offbreak
# ..   ...              ...        ...         ...                 ...
# 515  519      Subroto Das        NaN         NaN                 NaN
# 516  520     K Srinivasan        NaN         NaN                 NaN
# 517  521        VK Sharma        NaN         NaN                 NaN
# 518  523      AV Wankhade  14-Mar-92  Right_Hand                 NaN
# 519  524      B Aparajith   8-Jul-94  Right_Hand  Right-arm offbreak
#
#                f  g   h
# 0          India  0 NaN
# 1    New Zealand  0 NaN
# 2      Australia  0 NaN
# 3       Pakistan  0 NaN
# ...

# %%
df = pd.read_csv('G:/PANDAS/Datasets/Player_new_seperator.csv',sep='#',na_values=['SC Ganguly',"BB McCullum"])

# %%
df
# Out:
#      Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0            1              NaN   8-Jul-72    Left_Hand    Right-arm medium
# 1            2              NaN  27-Sep-81   Right_Hand    Right-arm medium
# 2            3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3            4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4            5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
# ..         ...              ...        ...          ...                 ...
# 518        519      Subroto Das        NaN          NaN                 NaN
# 519        520     K Srinivasan        NaN          NaN                 NaN
# 520        521        VK Sharma        NaN          NaN                 NaN
# 521        523      AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524      B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#          Country  Is_Umpire  Unnamed: 7
# ...

# %%
df = pd.read_csv('G:/PANDAS/Datasets/Player_new_seperator.csv',sep='#')

# %%
df
# Out:
#      Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0            1       SC Ganguly   8-Jul-72    Left_Hand    Right-arm medium
# 1            2      BB McCullum  27-Sep-81   Right_Hand    Right-arm medium
# 2            3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3            4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4            5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
# ..         ...              ...        ...          ...                 ...
# 518        519      Subroto Das        NaN          NaN                 NaN
# 519        520     K Srinivasan        NaN          NaN                 NaN
# 520        521        VK Sharma        NaN          NaN                 NaN
# 521        523      AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524      B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#          Country  Is_Umpire  Unnamed: 7
# ...

# %%
df1 = pd.read_csv('G:/PANDAS/Datasets/Player_new_seperator.csv',sep='#',skiprows=[0,1,2])

# %%
df1
# Out:
#        3       RT Ponting  19-Dec-74  Right_Hand    Right-arm medium  \
# 0      4        DJ Hussey  15-Jul-77  Right_Hand  Right-arm offbreak
# 1      5  Mohammad Hafeez  17-Oct-80  Right_Hand  Right-arm offbreak
# 2      6         R Dravid  11-Jan-73  Right_Hand  Right-arm offbreak
# 3      7         W Jaffer  16-Feb-78  Right_Hand  Right-arm offbreak
# 4      8          V Kohli   5-Nov-88  Right_Hand    Right-arm medium
# ..   ...              ...        ...         ...                 ...
# 515  519      Subroto Das        NaN         NaN                 NaN
# 516  520     K Srinivasan        NaN         NaN                 NaN
# 517  521        VK Sharma        NaN         NaN                 NaN
# 518  523      AV Wankhade  14-Mar-92  Right_Hand                 NaN
# 519  524      B Aparajith   8-Jul-94  Right_Hand  Right-arm offbreak
#
#      Australia  0  Unnamed: 7
# 0    Australia  0         NaN
# 1     Pakistan  0         NaN
# 2        India  0         NaN
# ...

# %%
df
# Out:
#      Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0            1       SC Ganguly   8-Jul-72    Left_Hand    Right-arm medium
# 1            2      BB McCullum  27-Sep-81   Right_Hand    Right-arm medium
# 2            3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3            4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4            5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
# ..         ...              ...        ...          ...                 ...
# 518        519      Subroto Das        NaN          NaN                 NaN
# 519        520     K Srinivasan        NaN          NaN                 NaN
# 520        521        VK Sharma        NaN          NaN                 NaN
# 521        523      AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524      B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#          Country  Is_Umpire  Unnamed: 7
# ...

# %%
df.head()
# Out:
#    Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0          1       SC Ganguly   8-Jul-72    Left_Hand    Right-arm medium
# 1          2      BB McCullum  27-Sep-81   Right_Hand    Right-arm medium
# 2          3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3          4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4          5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
#
#        Country  Is_Umpire  Unnamed: 7
# 0        India          0         NaN
# 1  New Zealand          0         NaN
# 2    Australia          0         NaN
# 3    Australia          0         NaN
# 4     Pakistan          0         NaN

# %%
df.describe()
# Out:
#         Player_Id   Is_Umpire  Unnamed: 7
# count  523.000000  523.000000   12.000000
# mean   262.003824    0.099426    6.500000
# std    151.127981    0.299520    3.605551
# min      1.000000    0.000000    1.000000
# 25%    131.500000    0.000000    3.750000
# 50%    262.000000    0.000000    6.500000
# 75%    392.500000    0.000000    9.250000
# max    524.000000    1.000000   12.000000

# %%
df.dtypes
# Out:
# Player_Id          int64
# Player_Name       object
# DOB               object
# Batting_Hand      object
# Bowling_Skill     object
# Country           object
# Is_Umpire          int64
# Unnamed: 7       float64
# dtype: object

# %%
df1.dtypes
# Out:
# 3                     int64
# RT Ponting           object
# 19-Dec-74            object
# Right_Hand           object
# Right-arm medium     object
# Australia            object
# 0                     int64
# Unnamed: 7          float64
# dtype: object

# %%
df1 = pd.read_csv('G:/PANDAS/Datasets/Player_new_seperator.csv',sep='#')

# %%
df1
# Out:
#      Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0            1       SC Ganguly   8-Jul-72    Left_Hand    Right-arm medium
# 1            2      BB McCullum  27-Sep-81   Right_Hand    Right-arm medium
# 2            3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3            4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4            5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
# ..         ...              ...        ...          ...                 ...
# 518        519      Subroto Das        NaN          NaN                 NaN
# 519        520     K Srinivasan        NaN          NaN                 NaN
# 520        521        VK Sharma        NaN          NaN                 NaN
# 521        523      AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524      B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#          Country  Is_Umpire  Unnamed: 7
# ...

# %%
df1.to_csv("G:/PANDAS/Datasets/result.csv",index=False,sep = "#", columns=['Player_Id','DOB'])

# %%
df = pd.read_csv('G:/PANDAS/Datasets/Player_new_seperator.csv',sep='#')

# %%
df
# Out:
#      Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0            1       SC Ganguly   8-Jul-72    Left_Hand    Right-arm medium
# 1            2      BB McCullum  27-Sep-81   Right_Hand    Right-arm medium
# 2            3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3            4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4            5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
# ..         ...              ...        ...          ...                 ...
# 518        519      Subroto Das        NaN          NaN                 NaN
# 519        520     K Srinivasan        NaN          NaN                 NaN
# 520        521        VK Sharma        NaN          NaN                 NaN
# 521        523      AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524      B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#          Country  Is_Umpire  Unnamed: 7
# ...

# %%
df.tail()
# Out:
#      Player_Id   Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 518        519   Subroto Das        NaN          NaN                 NaN
# 519        520  K Srinivasan        NaN          NaN                 NaN
# 520        521     VK Sharma        NaN          NaN                 NaN
# 521        523   AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524   B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#     Country  Is_Umpire  Unnamed: 7
# 518   India          1         NaN
# 519   India          1         NaN
# 520   India          1         NaN
# 521   India          0         NaN
# 522   India          0         NaN

# %%
df.columns
# Out:
# Index(['Player_Id', 'Player_Name', 'DOB', 'Batting_Hand', 'Bowling_Skill',
#        'Country', 'Is_Umpire', 'Unnamed: 7'],
#       dtype='object')

# %%
df['Player_Id']
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 518    519
# 519    520
# 520    521
# 521    523
# 522    524
# Name: Player_Id, Length: 523, dtype: int64

# %%
type(df['Player_Id'])
# Out:
# <class 'pandas.core.series.Series'>

# %%
df[['Player_Id']]
# Out:
#      Player_Id
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
# ..         ...
# 518        519
# 519        520
# 520        521
# 521        523
# 522        524
#
# [523 rows x 1 columns]

# %%
type(df[['Player_Id']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['Player_Id', 'Batting_Hand']]
# Out:
#      Player_Id Batting_Hand
# 0            1    Left_Hand
# 1            2   Right_Hand
# 2            3   Right_Hand
# 3            4   Right_Hand
# 4            5   Right_Hand
# ..         ...          ...
# 518        519          NaN
# 519        520          NaN
# 520        521          NaN
# 521        523   Right_Hand
# 522        524   Right_Hand
#
# [523 rows x 2 columns]

# %%
df[['Is_Umpire' , 'Player_Id' , 'Batting_Hand']]
# Out:
#      Is_Umpire  Player_Id Batting_Hand
# 0            0          1    Left_Hand
# 1            0          2   Right_Hand
# 2            0          3   Right_Hand
# 3            0          4   Right_Hand
# 4            0          5   Right_Hand
# ..         ...        ...          ...
# 518          1        519          NaN
# 519          1        520          NaN
# 520          1        521          NaN
# 521          0        523   Right_Hand
# 522          0        524   Right_Hand
#
# [523 rows x 3 columns]

# %%
df2 = pd.read_excel('G:/PANDAS/Datasets/LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx',sheet_name='Create your instrument universe')

# %%
df2
# Out:
#     Unnamed: 0  Unnamed: 1 Unnamed: 2  Unnamed: 3    Unnamed: 4 Unnamed: 5  \
# 0          NaN         NaN        NaN         NaN           NaN        NaN
# 1          NaN         NaN        NaN         NaN           NaN        NaN
# 2          NaN         NaN        NaN         NaN           NaN        NaN
# 3          NaN         NaN        NaN         NaN           NaN        NaN
# 4          NaN         NaN        NaN         NaN           NaN        NaN
# ..         ...         ...        ...         ...           ...        ...
# 66         NaN         NaN        NaN         NaN  BBG0000D14P3     Active
# 67         NaN         NaN        NaN         NaN  BBG00FN3B5K8     Active
# 68         NaN         NaN        NaN         NaN  BBG000DQQNJ8     Active
# 69         NaN         NaN        NaN         NaN  BBG000BF6B57     Active
# 70         NaN         NaN        NaN         NaN  BBG000BRVH05     Active
#
# ...

# %%
df4 = pd.read_html("https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool")

# %%
df4
# Out:
# [       Season   Age                                     Tm  \
#  0     2008-09  19.0  Did Not Play (other pro league—Spain)
#  1     2009-10  20.0                                    OKC
#  2     2010-11  21.0                                    OKC
#  3     2011-12  22.0                                    OKC
#  4     2012-13  23.0                                    OKC
#  5     2013-14  24.0                                    OKC
#  6     2014-15  25.0                                    OKC
#  7     2015-16  26.0                                    OKC
#  8     2016-17  27.0                                    TOT
#  9     2016-17  27.0                                    ORL
#  10    2016-17  27.0                                    TOR
#  11    2017-18  28.0                                    TOR
#  12    2018-19  29.0                                    TOR
#  13    2019-20  30.0                                    TOR
#  14    2020-21  31.0                                    LAC
# ...

# %%
type(df4)
# Out:
# list

# %%
len(df4)
# Out:
# 7

# %%
df4[0]
# Out:
#        Season   Age                                     Tm  \
# 0     2008-09  19.0  Did Not Play (other pro league—Spain)
# 1     2009-10  20.0                                    OKC
# 2     2010-11  21.0                                    OKC
# 3     2011-12  22.0                                    OKC
# 4     2012-13  23.0                                    OKC
# 5     2013-14  24.0                                    OKC
# 6     2014-15  25.0                                    OKC
# 7     2015-16  26.0                                    OKC
# 8     2016-17  27.0                                    TOT
# 9     2016-17  27.0                                    ORL
# 10    2016-17  27.0                                    TOR
# 11    2017-18  28.0                                    TOR
# 12    2018-19  29.0                                    TOR
# 13    2019-20  30.0                                    TOR
# 14    2020-21  31.0                                    LAC
# ...

# %%
df4[3].to_csv("G:\PANDAS\Datasets\players_data.csv")

# %%
df9=pd.read_html('''https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool
''')

# %%
df9[0]
# Out:
#        Season   Age                                     Tm  \
# 0     2008-09  19.0  Did Not Play (other pro league—Spain)
# 1     2009-10  20.0                                    OKC
# 2     2010-11  21.0                                    OKC
# 3     2011-12  22.0                                    OKC
# 4     2012-13  23.0                                    OKC
# 5     2013-14  24.0                                    OKC
# 6     2014-15  25.0                                    OKC
# 7     2015-16  26.0                                    OKC
# 8     2016-17  27.0                                    TOT
# 9     2016-17  27.0                                    ORL
# 10    2016-17  27.0                                    TOR
# 11    2017-18  28.0                                    TOR
# 12    2018-19  29.0                                    TOR
# 13    2019-20  30.0                                    TOR
# 14    2020-21  31.0                                    LAC
# ...

# %%
html_data = pd.read_html("https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool")
for i in range(len(html_data)):
    html_data[i].to_csv(f"G:\PANDAS\Datasets\html_data{i}.csv", index=False)

# %%
pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
s = """{
"name" :"sudh",
"phone_no" : 45454545,
"comp":["iNeuron", "EY" , "unilver" , "verizon" , "deloitte" , "wipro"]
}
"""

# %%
import json

# %%
s1 = json.loads(s)

# %%
s1
# Out:
# {'name': 'sudh',
#  'phone_no': 45454545,
#  'comp': ['iNeuron', 'EY', 'unilver', 'verizon', 'deloitte', 'wipro']}

# %%
pd.DataFrame(s1,columns=['comp'])
# Out:
#        comp
# 0   iNeuron
# 1        EY
# 2   unilver
# 3   verizon
# 4  deloitte
# 5     wipro

# %%
import requests

# %%
res = requests.get('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
res
# Out:
# <Response [200]>

# %%
js = res.json()

# %%
js
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50919',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50919/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50919/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50919/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50919',
#   'id': 1551753471,
#   'node_id': 'PR_kwDOAA0YD85IQo4h',
#   'number': 50919,
#   'title': 'Circleci project setup',
#   'user': {'login': 'Hexx333',
#    'id': 116751160,
#    'node_id': 'U_kgDOBvV7OA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/116751160?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Hexx333',
#    'html_url': 'https://github.com/Hexx333',
#    'followers_url': 'https://api.github.com/users/Hexx333/followers',
# ...

# %%
js[0]['title']
# Out:
# 'Circleci project setup'

# %%
for i in range(len(js)):
    print(js[i]['title'])
# Out:
# Circleci project setup
# ENH: Optimize replace to avoid copying when not necessary
# ENH: Make shallow copy for align nocopy with CoW
# ENH: Add tst for asfreq CoW when doing noop
# CLN: Use np.random.RandomState instead of tm.RNGContext
# REF: standardize reso-return in parsing
# REF: Define methods on resample non-dynamically
# Changes how the latest version is taken from a list of versions and cuts out obsolete versions on the homepage
# TST: read_fwf with dtype_backend
# ENH: Add dtype_backend to to_numeric
# DEPR: casting strings to float in to_datetime with unit
# DEPR: Remove (Int|UInt|Float)64Index
# API: parsing Timestamp("2014Q2")
# BUG: when inner/outer-joining dataframes with categorical MultiIndex, the output index dtype depends on row ordering
# Split orient
# ENH: Use circular weakref to delay copy in setitem
# ENH: pd.NA comparison with time, date, timedelta
# CLN: Refactor block splitting into its own method
# WIP: Trigger preview of the web/docs
# ...

# %%
len(js)
# Out:
# 30

# %%
js
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50919',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50919/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50919/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50919/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50919',
#   'id': 1551753471,
#   'node_id': 'PR_kwDOAA0YD85IQo4h',
#   'number': 50919,
#   'title': 'Circleci project setup',
#   'user': {'login': 'Hexx333',
#    'id': 116751160,
#    'node_id': 'U_kgDOBvV7OA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/116751160?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Hexx333',
#    'html_url': 'https://github.com/Hexx333',
#    'followers_url': 'https://api.github.com/users/Hexx333/followers',
# ...

# %%
df4 = pd.DataFrame(js)

# %%
df4.to_csv('G:\PANDAS\Datasets\json_dump.csv')

# %%
js[0]['user']
# Out:
# {'login': 'Hexx333',
#  'id': 116751160,
#  'node_id': 'U_kgDOBvV7OA',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/116751160?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/Hexx333',
#  'html_url': 'https://github.com/Hexx333',
#  'followers_url': 'https://api.github.com/users/Hexx333/followers',
#  'following_url': 'https://api.github.com/users/Hexx333/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/Hexx333/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/Hexx333/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/Hexx333/subscriptions',
#  'organizations_url': 'https://api.github.com/users/Hexx333/orgs',
#  'repos_url': 'https://api.github.com/users/Hexx333/repos',
#  'events_url': 'https://api.github.com/users/Hexx333/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/Hexx333/received_events',
#  'type': 'User',
#  'site_admin': False}

# %%
pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")

# %%
lis=[]
for i in range(len(js)):
    lis.append(js[i]['user'])
pd.DataFrame(lis)
# Out:
#                  login         id               node_id  \
# 0              Hexx333  116751160          U_kgDOBvV7OA
# 1                phofl   61934744  MDQ6VXNlcjYxOTM0NzQ0
# 2                phofl   61934744  MDQ6VXNlcjYxOTM0NzQ0
# 3                phofl   61934744  MDQ6VXNlcjYxOTM0NzQ0
# 4            mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 5         jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 6            mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 7        JustinAmstadt  100241650          U_kgDOBfmQ8g
# 8            mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 9            mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 10        jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 11          topper-123   26364415  MDQ6VXNlcjI2MzY0NDE1
# 12        jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 13          mcrumiller    1896992  MDQ6VXNlcjE4OTY5OTI=
# 14           labibdotc   98433990          U_kgDOBd37xg
# 15           lithomas1   47963215  MDQ6VXNlcjQ3OTYzMjE1
# ...

# %%
user = []
res=requests.get('https://api.github.com/repos/pandas-dev/pandas/issues')
js=res.json()
for i in range(len(js)):
    user.append(js[i]['user'])

pd.DataFrame(user)
# Out:
#                  login         id               node_id  \
# 0              Hexx333  116751160          U_kgDOBvV7OA
# 1                phofl   61934744  MDQ6VXNlcjYxOTM0NzQ0
# 2                phofl   61934744  MDQ6VXNlcjYxOTM0NzQ0
# 3                phofl   61934744  MDQ6VXNlcjYxOTM0NzQ0
# 4            mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 5         jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 6            mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 7        JustinAmstadt  100241650          U_kgDOBfmQ8g
# 8            mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 9            mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 10        jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 11          topper-123   26364415  MDQ6VXNlcjI2MzY0NDE1
# 12        jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 13          mcrumiller    1896992  MDQ6VXNlcjE4OTY5OTI=
# 14           labibdotc   98433990          U_kgDOBd37xg
# 15           lithomas1   47963215  MDQ6VXNlcjQ3OTYzMjE1
# ...

# %%
pd.DataFrame([js[i]["user"] for i in range(len(js))])
# Out:
#                  login         id               node_id  \
# 0              Hexx333  116751160          U_kgDOBvV7OA
# 1                phofl   61934744  MDQ6VXNlcjYxOTM0NzQ0
# 2                phofl   61934744  MDQ6VXNlcjYxOTM0NzQ0
# 3                phofl   61934744  MDQ6VXNlcjYxOTM0NzQ0
# 4            mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 5         jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 6            mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 7        JustinAmstadt  100241650          U_kgDOBfmQ8g
# 8            mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 9            mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 10        jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 11          topper-123   26364415  MDQ6VXNlcjI2MzY0NDE1
# 12        jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 13          mcrumiller    1896992  MDQ6VXNlcjE4OTY5OTI=
# 14           labibdotc   98433990          U_kgDOBd37xg
# 15           lithomas1   47963215  MDQ6VXNlcjQ3OTYzMjE1
# ...

# %%
l = []
for i in range(len(js)):
    l.append(js[i]['user'])
    
pd.DataFrame(l)
# Out:
#                  login         id               node_id  \
# 0              Hexx333  116751160          U_kgDOBvV7OA
# 1                phofl   61934744  MDQ6VXNlcjYxOTM0NzQ0
# 2                phofl   61934744  MDQ6VXNlcjYxOTM0NzQ0
# 3                phofl   61934744  MDQ6VXNlcjYxOTM0NzQ0
# 4            mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 5         jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 6            mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 7        JustinAmstadt  100241650          U_kgDOBfmQ8g
# 8            mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 9            mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 10        jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 11          topper-123   26364415  MDQ6VXNlcjI2MzY0NDE1
# 12        jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 13          mcrumiller    1896992  MDQ6VXNlcjE4OTY5OTI=
# 14           labibdotc   98433990          U_kgDOBd37xg
# 15           lithomas1   47963215  MDQ6VXNlcjQ3OTYzMjE1
# ...

# %%
json_data = pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
data = pd.DataFrame.from_records(json_data['user'])
data.head()
# Out:
#        login         id               node_id  \
# 0    Hexx333  116751160          U_kgDOBvV7OA
# 1      phofl   61934744  MDQ6VXNlcjYxOTM0NzQ0
# 2      phofl   61934744  MDQ6VXNlcjYxOTM0NzQ0
# 3      phofl   61934744  MDQ6VXNlcjYxOTM0NzQ0
# 4  mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/116751...
# 1  https://avatars.githubusercontent.com/u/619347...
# 2  https://avatars.githubusercontent.com/u/619347...
# 3  https://avatars.githubusercontent.com/u/619347...
# 4  https://avatars.githubusercontent.com/u/106470...
#
#                                       url                      html_url  \
# 0    https://api.github.com/users/Hexx333    https://github.com/Hexx333
# 1      https://api.github.com/users/phofl      https://github.com/phofl
# 2      https://api.github.com/users/phofl      https://github.com/phofl
# ...
